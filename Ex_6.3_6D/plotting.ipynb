# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle as pkl

# %%
# with open("results/PINN_t2/losshist.pkl",'rb') as pfile:
#     hist = pkl.load(pfile)


with open("results/DRM_paper/losshist.pkl",'rb') as pfile:
    hist = pkl.load(pfile)

# %%
plt.plot(hist,label='loss')
plt.yscale('linear')
plt.legend()
